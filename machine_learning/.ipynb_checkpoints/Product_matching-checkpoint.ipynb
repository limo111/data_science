# %%
###loading large file 
import pandas as pd

# %%
import os

# %%
os.listdir('../data/online_retail_II.csv')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 os.listdir('../data/online_retail_II.csv')
#
# NotADirectoryError: [Errno 20] Not a directory: '../data/online_retail_II.csv'

# %%
#https://www.kaggle.com/datasets/mashlyn/online-retail-ii-uci, downloaded from kaggle
data=pd.read_csv('../data/online_retail_II.csv')### due to computation and memory constraints this 92 MB file is assumed to be a big data file

# %%
##in reality if the data is huge we take a sample of the data and train models on that, since the data here is for 13 months only
##when we aggregate the complete data has been taken

# %%
##we can take a sample and get modeling insights using data science
data
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                      ...    ...          ...             ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France
#
# [1067371 rows x 8 columns]

# %% [markdown]
# # Checking for Null Values and Imputing Them.

# %%
data.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
data['Customer ID']=data['Customer ID'].fillna(0)
data['Description']=data['Description'].fillna('Desc missing')

# %%
###for unregistered guest customer the customer id is taken as 0

# %%
data['Customer ID']=data['Customer ID'].astype(int)

# %%
data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95        13085  United Kingdom
# 1  2009-12-01 07:45:00   6.75        13085  United Kingdom
# 2  2009-12-01 07:45:00   6.75        13085  United Kingdom
# 3  2009-12-01 07:45:00   2.10        13085  United Kingdom
# 4  2009-12-01 07:45:00   1.25        13085  United Kingdom

# %%
data[data.duplicated()]
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 371      489517     21912           VINTAGE SNAKES & LADDERS         1
# 383      489517     22130   PARTY CONE CHRISTMAS DECORATION          6
# 384      489517     22319  HAIRCLIPS FORTIES FABRIC ASSORTED        12
# 385      489517     21913     VINTAGE SEASIDE JIGSAW PUZZLES         1
# 386      489517     21821   GLITTER STAR GARLAND WITH BELLS          1
# ...         ...       ...                                ...       ...
# 1067136  581538     22068        BLACK PIRATE TREASURE CHEST         1
# 1067150  581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 1067153  581538     22992             REVOLVER WOODEN RULER          1
# 1067160  581538     22694                       WICKER STAR          1
# 1067162  581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                  InvoiceDate  Price  Customer ID         Country
# 371      2009-12-01 11:34:00   3.75        16329  United Kingdom
# 383      2009-12-01 11:34:00   0.85        16329  United Kingdom
# 384      2009-12-01 11:34:00   0.65        16329  United Kingdom
# 385      2009-12-01 11:34:00   3.75        16329  United Kingdom
# 386      2009-12-01 11:34:00   3.75        16329  United Kingdom
# ...                      ...    ...          ...             ...
# 1067136  2011-12-09 11:34:00   0.39        14446  United Kingdom
# 1067150  2011-12-09 11:34:00   2.49        14446  United Kingdom
# 1067153  2011-12-09 11:34:00   1.95        14446  United Kingdom
# 1067160  2011-12-09 11:34:00   2.10        14446  United Kingdom
# 1067162  2011-12-09 11:34:00   2.08        14446  United Kingdom
#
# [34335 rows x 8 columns]

# %%
###we can use market basket analysis for data driven insights
data['transaction_month'] = pd.DatetimeIndex(data['InvoiceDate']).month
data['transaction_year'] = pd.DatetimeIndex(data['InvoiceDate']).year
grouping_cols=['Invoice','transaction_month','transaction_year']

# %%
data[data.duplicated(subset=grouping_cols, keep=False)]
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  \
# 0        2009-12-01 07:45:00   6.95        13085  United Kingdom
# 1        2009-12-01 07:45:00   6.75        13085  United Kingdom
# 2        2009-12-01 07:45:00   6.75        13085  United Kingdom
# 3        2009-12-01 07:45:00   2.10        13085  United Kingdom
# 4        2009-12-01 07:45:00   1.25        13085  United Kingdom
# ...                      ...    ...          ...             ...
# 1067366  2011-12-09 12:50:00   2.10        12680          France
# 1067367  2011-12-09 12:50:00   4.15        12680          France
# 1067368  2011-12-09 12:50:00   4.15        12680          France
# 1067369  2011-12-09 12:50:00   4.95        12680          France
# 1067370  2011-12-09 12:50:00  18.00        12680          France
#
#          transaction_month  transaction_year
# 0                       12              2009
# 1                       12              2009
# 2                       12              2009
# 3                       12              2009
# 4                       12              2009
# ...                    ...               ...
# 1067366                 12              2011
# 1067367                 12              2011
# 1067368                 12              2011
# 1067369                 12              2011
# 1067370                 12              2011
#
# [1054077 rows x 10 columns]

# %%
agg_data_quant_sold_by_month_year=data.groupby(['transaction_month','transaction_year'])["Quantity"].sum()

# %%
agg_data_quant_sold_by_month_year=agg_data_quant_sold_by_month_year.reset_index().sort_values(['transaction_year','transaction_month'])

# %%
agg_data_quant_sold_by_month_year.columns
# Out:
# Index(['transaction_month', 'transaction_year', 'Quantity'], dtype='object')

# %%
agg_data_quant_sold_by_month_year['timestamp']=agg_data_quant_sold_by_month_year.apply(lambda x:str(x['transaction_year'])+'-'+str(x['transaction_month']),axis=1)

# %%
agg_data_quant_sold_by_month_year.drop(columns=['transaction_month','transaction_year'],axis=1,inplace=True)

# %%
agg_data_quant_sold_by_month_year.set_index('timestamp',inplace=True)

# %%
agg_data_quant_sold_by_month_year
# Out:
#            Quantity
# timestamp
# 2009-12      420088
# 2010-1       375363
# 2010-2       368402
# 2010-3       489370
# 2010-4       351971
# 2010-5       364095
# 2010-6       388253
# 2010-7       302201
# 2010-8       451803
# 2010-9       478262
# 2010-10      601729
# 2010-11      673856
# 2010-12      508876
# 2011-1       308966
# 2011-2       277989
# 2011-3       351872
# 2011-4       289098
# 2011-5       380391
# 2011-6       341623
# 2011-7       391116
# 2011-8       406199
# 2011-9       549817
# 2011-10      570532
# 2011-11      740286
# 2011-12      226334

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pmdarima
from pmdarima.arima import auto_arima
pd.set_option('display.float_format', lambda x: '%20f' % x)

# %%
# Train Test Split Index
split_idx=int(len(agg_data_quant_sold_by_month_year)*0.95)

# Split
train = agg_data_quant_sold_by_month_year.iloc[:split_idx]
val = agg_data_quant_sold_by_month_year.iloc[split_idx:]
# Visualize split
fig,ax= plt.subplots(figsize=(12,12))
kws = dict(marker='o')
plt.plot(train, label='Train', **kws)
plt.plot(val, label='val', **kws)
plt.xticks(rotation=90)
ax.legend(bbox_to_anchor=[1,1]);

# %%
val
# Out:
#            Quantity
# timestamp
# 2011-11      740286
# 2011-12      226334

# %% [markdown]
# # Applying the AUTO ARIMA MODEL

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp39-cp39-macosx_11_0_arm64.whl (580 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 580.2/580.2 kB 7.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.19 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: urllib3 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pmdarima) (1.26.13)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pmdarima) (65.6.3)
# Requirement already satisfied: numpy>=1.21.2 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pmdarima) (1.23.2)
# Collecting statsmodels>=0.13.2
#   Downloading statsmodels-0.13.5-cp39-cp39-macosx_11_0_arm64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 7.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy>=1.3.2 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pmdarima) (1.9.3)
# Requirement already satisfied: joblib>=0.11 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pmdarima) (1.2.0)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from statsmodels>=0.13.2->pmdarima) (22.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: patsy, Cython, statsmodels, pmdarima
# Successfully installed Cython-0.29.33 patsy-0.5.3 pmdarima-2.0.3 statsmodels-0.13.5
# Note: you may need to restart the kernel to use updated packages.

# %%
model = auto_arima(train, start_p=0, start_q=0,seasonal=False)
model.summary()
##seasonal components are (000), p value is 1 , d we need to check and q value is 0
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   23
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -293.731
# Date:                Tue, 28 Mar 2023   AIC                            593.461
# Time:                        16:42:06   BIC                            596.868
# Sample:                    12-01-2009   HQIC                           594.318
#                          - 10-01-2011
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    1.69e+05   8.87e+04      1.906      0.057   -4808.596    3.43e+05
# ar.L1          0.6039      0.189      3.187      0.001       0.233       0.975
# sigma2      7.419e+09      0.069   1.08e+11      0.000    7.42e+09    7.42e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.58   Jarque-Bera (JB):                 0.61
# Prob(Q):                              0.45   Prob(JB):                         0.74
# Heteroskedasticity (H):               1.03   Skew:                             0.09
# Prob(H) (two-sided):                  0.97   Kurtosis:                         2.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.77e+28. Standard errors may be unstable.
# """

# %%
model.plot_diagnostics()

# %%
from pmdarima.utils import c, diff

x = c(train['Quantity'])
values=diff(x, differences=1)

# %%
values
# Out:
# array([ -44725.,   -6961.,  120968., -137399.,   12124.,   24158.,
#         -86052.,  149602.,   26459.,  123467.,   72127., -164980.,
#        -199910.,  -30977.,   73883.,  -62774.,   91293.,  -38768.,
#          49493.,   15083.,  143618.,   20715.])

# %% [markdown]
# # Testing the Hypothesis

# %%
from statsmodels.tsa.stattools import adfuller
def adfuller_test(values):
    result=adfuller(values)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    return result

result=adfuller_test(values)
if result[1] <= 0.05:
    print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
else:
    print("weak evidence against null hypothesis,indicating it is non-stationary ")
# Out:
# ADF Test Statistic : -4.4665059857209854
# p-value : 0.00022593613213257475
# #Lags Used : 0
# Number of Observations : 21
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary

# %%
##d value is 1 difference
#p=1
#q=0
x = c(train['Quantity'])
differenced_train=diff(x, differences=1)

# %%
train
# Out:
#            Quantity
# timestamp
# 2009-12      420088
# 2010-1       375363
# 2010-2       368402
# 2010-3       489370
# 2010-4       351971
# 2010-5       364095
# 2010-6       388253
# 2010-7       302201
# 2010-8       451803
# 2010-9       478262
# 2010-10      601729
# 2010-11      673856
# 2010-12      508876
# 2011-1       308966
# 2011-2       277989
# 2011-3       351872
# 2011-4       289098
# 2011-5       380391
# 2011-6       341623
# 2011-7       391116
# 2011-8       406199
# 2011-9       549817
# 2011-10      570532

# %%
from statsmodels.tsa.arima.model import ARIMA
from matplotlib import pyplot

model_1 = ARIMA(train, order=(1,1, 0))
model_fit = model_1.fit()
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
# /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                          0
# count            23.000000
# mean          26152.215693
# std          127544.965009
# min         -209203.411155
# 25%          -37931.726692
# 50%           24840.951369
# 75%           83419.434487
# max          420088.000000

# %% [markdown]
# # Forecasting the Results

# %%
forecast = model_fit.get_forecast(steps=2)
yhat = forecast.predicted_mean
yhat_conf_int = forecast.conf_int(alpha=0.05)

# %%
yhat##predicted values
# Out:
# 2011-11-01          569365.113031
# 2011-12-01          569430.844395
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
yhat_conf_int###predicted confidence intervals
# Out:
#                  lower Quantity       upper Quantity
# 2011-11-01        379866.282625        758863.943438
# 2011-12-01        308877.734903        829983.953887

# %%
val###actual values
# Out:
#            Quantity
# timestamp
# 2011-11      740286
# 2011-12      226334

# %%
import sklearn
sklearn.metrics.mean_absolute_percentage_error(val['Quantity'],yhat)
# Out:
# 0.8733861370315883

# %%
val['Quantity']
# Out:
# timestamp
# 2011-11    740286
# 2011-12    226334
# Name: Quantity, dtype: int64

# %% [markdown]
# ##LStM

# %%
train.head()
# Out:
#            Quantity
# timestamp
# 2009-12      420088
# 2010-1       375363
# 2010-2       368402
# 2010-3       489370
# 2010-4       351971

# %%
train.plot()
# Out:
# <AxesSubplot: xlabel='timestamp'>

# %%
import numpy as np
def sampling(sequence, step_num):
    x_values=[]
    y_values=[]
    for index in range(len(sequence)):
        step = index + step_num
        if not (step > len(sequence)-1):
            x, y = sequence[index:step], sequence[step]
            x_values.append(x)
            y_values.append(y)
    return np.array(x_values), np.array(y_values)

# %%
train
# Out:
#            Quantity
# timestamp
# 2009-12      420088
# 2010-1       375363
# 2010-2       368402
# 2010-3       489370
# 2010-4       351971
# 2010-5       364095
# 2010-6       388253
# 2010-7       302201
# 2010-8       451803
# 2010-9       478262
# 2010-10      601729
# 2010-11      673856
# 2010-12      508876
# 2011-1       308966
# 2011-2       277989
# 2011-3       351872
# 2011-4       289098
# 2011-5       380391
# 2011-6       341623
# 2011-7       391116
# 2011-8       406199
# 2011-9       549817
# 2011-10      570532

# %%
val
# Out:
#            Quantity
# timestamp
# 2011-11      740286
# 2011-12      226334

# %%
step_num = 2

X_features, Y_features = sampling(train['Quantity'], step_num)

# %%
X_features.shape
# Out:
# (21, 2)

# %%
n_features = 1
X_features = X_features.reshape((X_features.shape[0], X_features.shape[1], n_features))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

model = Sequential()
model.add(LSTM(8, activation='relu', input_shape=(step_num, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mape')
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
#
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-03-28 16:43:02.018279: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-28 16:43:02.018628: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
history=model.fit(X_features, Y_features, epochs=200, verbose=0)
# Out:
# 2023-03-28 16:43:03.618726: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-28 16:43:03.934651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
from numpy import array

# %%
x_input=train['Quantity'].values[-2:]
x_input = x_input.reshape((1, step_num, n_features))
yhat1 = model.predict(x_input, verbose=0)
# Out:
# 2023-03-28 16:43:11.577238: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
yhat1.reshape(-1,)[0]
# Out:
# 69087.19

# %%
x_input=array([train['Quantity'].values[-1:][0],val['Quantity'].values[0]])
x_input = x_input.reshape((1, step_num, n_features))
yhat2 = model.predict(x_input, verbose=0)

# %%
val['Quantity'].values
[yhat1.reshape(-1,)[0],yhat2.reshape(-1,)[0]]
# Out:
# [69087.19, 79346.99]

# %%
sklearn.metrics.mean_absolute_percentage_error(val['Quantity'].values,[yhat1.reshape(-1,)[0],yhat2.reshape(-1,)[0]])
# Out:
# 0.7780501124826542

# %% [markdown]
# LSTM does a bad job here since it is a classic overfit case with less data for training

# %% [markdown]
# lets go with simpler model

# %% [markdown]
# holtwinters exponential smoothing

# %%
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
ts=agg_data_quant_sold_by_month_year
ts[['Quantity']].plot(title='Quantity')
x=12###year
alpha=1/(2*x)
ts['HW1'] = SimpleExpSmoothing(ts['Quantity']).fit(smoothing_level=alpha,optimized=False,use_brute=True).fittedvalues      
ts[['Quantity','HW1']].plot(title='Holt Winters exponential smoothing graph(single)')
split_idx = int(np.ceil(len(agg_data_quant_sold_by_month_year)*0.90))


# Split
train = ts['Quantity'].values[:split_idx]
train
val=ts['Quantity'].values[split_idx+1:]
# Visualize split
fig,ax= plt.subplots(figsize=(12,8))
kws = dict(marker='o')
plt.plot(train, label='Train', **kws)
plt.plot(val,label='test',**kws)
ax.legend(bbox_to_anchor=[1,1])
#ax.set_xticklabels(ts['Quantity'].index, rotation=70);
# Out:
# /Users/arvindramesh/miniconda3/envs/tensorflow/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
val
# Out:
# array([226334])

# %%
mean_absolute_percentage_error(ts['Quantity'].values[split_idx+1:],ts['HW1'].values[split_idx+1:])
# Out:
# 0.9219543840718701

# %%
###since the data above is very less for just 12 months all these models are overfit and giving bad results
##had we had more data the above models can be compared considered
# as of now the arima(0.87)>(holt winters exponential smoothing(0.92)>(LSTM 0.95))
#so far arima is doing a good job

# %% [markdown]
# Objective
# ●	To identify the method with which a healthy relationship between data-driven decision and data science making can help decision making by scrutinizing data and deriving insights from data.
# ##The method used here is ARIMA model and tried to predict the quantity demand for 2012- jan, with a absolute error of a large
# # if we tune the model further it will be reduced to a manageable number
# ●	To evaluate the relationship between data-driven decisions and data science that will help to make sound decisions.
# ##yes with help of data science modeling it is possible to identify the hidden patterns in the data
# ●	To analyze the benefits of using data science and data-driven decisions in helping companies make sound decisions.
# ##here if the model if finetuned further for reduced error, it can help in prediction of quantity of products sold and manage the warehouse accordingly
#
# ●	To analyze the disadvantages of data science and data-driven decisions in big companies' decision-making.
# ##here the error if you see is huge number , the model tells the yhat_conf_int tells that the confidence interval is huge range which
# ##will reduce once we start adding more data points, 13 is very less data points to start wth, so the data science and data driven
# ##are good only if the data is available
# ●	To find out the challenge of implementing  data-driven decision and data science making by the business.
# ## the data needs to be more, if the data is less the algorithms like ARIMA that was shown above does not yield accurate results
# ●	To purpose, solutions to be resolved in the relationship between data-driven decision and data science.
# ##work needs to be done to create more useful data then the data driven decisions can be taken on the basis of data science models.
